# %% [markdown]
# # Assignment 1: Python Fundamentals, NumPy, and Pandas
# Anton Laitakari

# %% [markdown]
# # Task 1

# %%
transactions = [
    {"id": 1, "product": "Laptop",   "price": 1200, "quantity":  2, "region": "EU"},
    {"id": 2, "product": "Phone",    "price":  800, "quantity": -1, "region": "US"},
    {"id": 3, "product": "Tablet",   "price":    0, "quantity":  5, "region": "EU"},
    {"id": 4, "product": "Monitor",  "price":  350, "quantity":  3, "region": "US"},
    {"id": 5, "product": "Laptop",   "price": 1200, "quantity":  1, "region": "EU"},
    {"id": 6, "product": "Keyboard", "price":   75, "quantity": 10, "region": "APAC"},
]
# a) Filter out transactions with zero price or negative quantity
valid_transactions = [
    t for t in transactions
    if t["price"] > 0 and t["quantity"] >= 0
]
# b) Add a 'total' field to each valid transaction
for t in valid_transactions:
    t["total"] = t["price"] * t["quantity"]
# c) Group by region and compute total revenue per region
revenue_by_region = {}
for t in valid_transactions:
    region = t["region"]
    revenue_by_region[region] = revenue_by_region.get(region, 0) + t["total"]

print("Revenue by region:", revenue_by_region)
# d) Print the region with the highest total revenue
top_region = max(revenue_by_region, key=revenue_by_region.get)
print(f"Top region: {top_region} with revenue {revenue_by_region[top_region]}")
# Out:
# Revenue by region: {'EU': 3600, 'US': 1050, 'APAC': 750}
# Top region: EU with revenue 3600

# %% [markdown]
# # Task 2

# %%
sales = [1200, 980, 1540, 870, 2010, 1650, 1300, 1100, 950, 1780, 2200, 1430, 1600, 1900]

def summarise_sales(s):
    total   = sum(s)
    average = round(total / len(s), 2)
    return {
        "total":               total,
        "average":             average,
        "best_day":            s.index(max(s)) + 1,
        "worst_day":           s.index(min(s)) + 1,
        "above_average_count": sum(1 for x in s if x > average),
    }

print(summarise_sales(sales))
# Out:
# {'total': 20510, 'average': 1465.0, 'best_day': 11, 'worst_day': 4, 'above_average_count': 7}

# %% [markdown]
# # Task 3

# %%
students = [
    {"name": "Anna", "grade": 85, "attendance": 0.92},
    {"name": "Erik", "grade": 58, "attendance": 0.75},
    {"name": "Mia",  "grade": 91, "attendance": 0.98},
    {"name": "Leo",  "grade": 44, "attendance": 0.60},
    {"name": "Sara", "grade": 72, "attendance": 0.88},
    {"name": "Tom",  "grade": 67, "attendance": 0.70},
    {"name": "Nina", "grade": 95, "attendance": 0.99},
    {"name": "Olli", "grade": 50, "attendance": 0.65},
]

# a) and b)
print("Passing students:", [s["name"] for s in students if s["grade"] >= 50])
# b)
for s in students:
    status = "Excellent" if s["grade"] >= 80 else "Pass" if s["grade"] >= 50 else "Fail"
    print(f"{s['name']}: {status}")
# c)
print(f"\nStudents with attendance below 0.80: {sum(1 for s in students if s['attendance'] < 0.80)}")
# d)
top = students[0]
for s in students[1:]:
    if s["grade"] > top["grade"]: top = s
print(f"\nTop student (loop): {top['name']} with grade {top['grade']}")
# e)
best = max(students, key=lambda s: s["grade"])
print(f"Top student (max): {best['name']} with grade {best['grade']}")
# Out:
# Passing students: ['Anna', 'Erik', 'Mia', 'Sara', 'Tom', 'Nina', 'Olli']
# Anna: Excellent
# Erik: Pass
# Mia: Excellent
# Leo: Fail
# Sara: Pass
# Tom: Pass
# Nina: Excellent
# Olli: Pass
#
# Students with attendance below 0.80: 4
#
# Top student (loop): Nina with grade 95
# Top student (max): Nina with grade 95

# %% [markdown]
# # Task 4

# %%
class Portfolio:
    def __init__(self, owner):
        self.owner, self.holdings = owner, {}

    def add_asset(self, t, s, p):
        h = self.holdings.setdefault(t, {"shares": 0})
        h["shares"] += s
        h["price_per_share"] = p

    def total_value(self):
        return sum(h["shares"] * h["price_per_share"] for h in self.holdings.values())

    def most_valuable(self):
        return max(self.holdings, key=lambda t: self.holdings[t]["shares"] * self.holdings[t]["price_per_share"])

    def __str__(self):
        return f"Portfolio of {self.owner} | Assets: {len(self.holdings)} | Total value: €{self.total_value():,.2f}"
# Portfolio
p = Portfolio("Anton")
p.add_asset("AAPL", 20, 500)
p.add_asset("MSFT", 5,1000)
p.add_asset("NVDA", 10, 2000)
p.add_asset("AAPL", 15, 420)

print(p)
print(f"Total portfolio value: €{p.total_value():,.2f}")
print(f"Most valuable asset: {p.most_valuable()}")
# Out:
# Portfolio of Anton | Assets: 3 | Total value: €39,700.00
# Total portfolio value: €39,700.00
# Most valuable asset: NVDA

# %% [markdown]
# # Task 5

# %%
from datetime import date

orders = [
    ("2025-01-15", "Laptop"),  ("2025-01-22", "Phone"),
    ("2025-02-03", "Laptop"),  ("2025-02-14", "Tablet"),
    ("2025-03-01", "Phone"),   ("2025-03-10", "Phone"),
    ("2025-03-22", "Laptop"),  ("2025-04-05", "Monitor"),
]

dates    = [date.fromisoformat(d) for d, _ in orders]
earliest = min(dates)
latest   = max(dates)

print(f"Earliest order: {earliest}")
print(f"Latest order:   {latest}")
print(f"Days between earliest and latest order: {(latest - earliest).days}")
# Out:
# Earliest order: 2025-01-15
# Latest order:   2025-04-05
# Days between earliest and latest order: 80

# %% [markdown]
# # Task 6

# %%
import numpy as np

# Rows: years (2022–2024), Columns: quarters (Q1–Q4)
revenue = np.array([
    [210, 230, 190, 250],
    [220, 260, 200, 270],
    [250, 290, 230, 310],
])
growth_factors = np.array([1.05, 1.03, 1.08, 1.02])

np.set_printoptions(precision=2)

# a) Total annual revenue per year (row sums)
print("Annual totals (2022–2024):       ", revenue.sum(axis=1))

# b) Mean quarterly revenue across all years (column means)
print("Mean quarterly revenue (Q1–Q4): ", revenue.mean(axis=0))

# c) Growth-adjusted 2024 row
print("Adjusted 2024 revenue:          ", revenue[2] * growth_factors)

# d) All values exceeding 250
print("Quarterly revenues above 250:   ", revenue[revenue > 250])
mask = revenue > 250
# Out:
# Annual totals (2022–2024):        [ 880  950 1080]
# Mean quarterly revenue (Q1–Q4):  [226.67 260.   206.67 276.67]
# Adjusted 2024 revenue:           [262.5 298.7 248.4 316.2]
# Quarterly revenues above 250:    [260 270 290 310]

# %% [markdown]
# # Task 7

# %%
import pandas as pd

# Example DataFrame (adjust if your data is already given)
df = pd.DataFrame({
    "name": ["Anna", "Erik", "Mia", "Leo", "Sara"],
    "department": ["Finance", "IT", "Finance", "HR", "Finance"],
    "salary": [50000, 60000, 75000, 40000, 65000],
    "years_exp": [5, 8, 10, 3, 7],
    "performance_score": [4.5, 3.8, 4.9, 3.5, 4.2]
})

print("Original DataFrame:\n", df, "\n")

# a) New column
df["salary_per_year_exp"] = (df["salary"] / df["years_exp"]).round().astype(int)
print("After adding salary_per_year_exp:\n", df, "\n")

# b) Sort and top 3
top3 = df.sort_values(by="performance_score", ascending=False).head(3)
print("Top 3 by performance_score:\n", top3, "\n")

# c) .loc filter
finance_high_perf = df.loc[
    (df["department"] == "Finance") & (df["performance_score"] > 4.0)
]
print("Finance employees with performance > 4.0:\n", finance_high_perf, "\n")

# d) Rename column
df = df.rename(columns={"years_exp": "experience_years"})
print("After renaming column:\n", df, "\n")

# e) .iloc selection
subset = df.iloc[:4, [2, 4]]  # salary and performance_score columns
print("First 4 employees (salary & performance_score):\n", subset)
# Out:
# Original DataFrame:
#     name department  salary  years_exp  performance_score
# 0  Anna    Finance   50000          5                4.5
# 1  Erik         IT   60000          8                3.8
# 2   Mia    Finance   75000         10                4.9
# 3   Leo         HR   40000          3                3.5
# 4  Sara    Finance   65000          7                4.2
#
# After adding salary_per_year_exp:
#     name department  salary  years_exp  performance_score  salary_per_year_exp
# 0  Anna    Finance   50000          5                4.5                10000
# 1  Erik         IT   60000          8                3.8                 7500
# 2   Mia    Finance   75000         10                4.9                 7500
# 3   Leo         HR   40000          3                3.5                13333
# 4  Sara    Finance   65000          7                4.2                 9286
#
# Top 3 by performance_score:
#     name department  salary  years_exp  performance_score  salary_per_year_exp
# 2   Mia    Finance   75000         10                4.9                 7500
# 0  Anna    Finance   50000          5                4.5                10000
# 4  Sara    Finance   65000          7                4.2                 9286
#
# Finance employees with performance > 4.0:
#     name department  salary  years_exp  performance_score  salary_per_year_exp
# 0  Anna    Finance   50000          5                4.5                10000
# 2   Mia    Finance   75000         10                4.9                 7500
# 4  Sara    Finance   65000          7                4.2                 9286
#
# After renaming column:
#     name department  salary  experience_years  performance_score  \
# 0  Anna    Finance   50000                 5                4.5
# 1  Erik         IT   60000                 8                3.8
# 2   Mia    Finance   75000                10                4.9
# 3   Leo         HR   40000                 3                3.5
# 4  Sara    Finance   65000                 7                4.2
#
#    salary_per_year_exp
# 0                10000
# 1                 7500
# 2                 7500
# 3                13333
# 4                 9286
#
# First 4 employees (salary & performance_score):
#     salary  performance_score
# 0   50000                4.5
# 1   60000                3.8
# 2   75000                4.9
# 3   40000                3.5

# %% [markdown]
# # Task 8

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(seed=123)
days = pd.date_range(start="2025-01-06", periods=28, freq="D")
visitors         = rng.integers(200, 600, size=28)
conversion_rate  = rng.uniform(0.02, 0.08, size=28).round(4)
avg_order_value  = rng.normal(50, 10, size=28).round(2)

# a) Create DataFrame with date as index
traffic = pd.DataFrame(
    {
        "visitors":        visitors,
        "conversion_rate": conversion_rate,
        "avg_order_value": avg_order_value,
    },
    index=days
)
traffic.index.name = "date"

# b) Compute conversions and daily_revenue
traffic["conversions"]    = (traffic["visitors"] * traffic["conversion_rate"]).round(0).astype(int)
traffic["daily_revenue"]  = traffic["conversions"] * traffic["avg_order_value"]

print(traffic.head(28).to_string())
# Out:
#             visitors  conversion_rate  avg_order_value  conversions  daily_revenue
# date
# 2025-01-06       206           0.0645            64.30           13         835.90
# 2025-01-07       472           0.0578            48.44           27        1307.88
# 2025-01-08       437           0.0756            43.26           33        1427.58
# 2025-01-09       221           0.0339            43.61            7         305.27
# 2025-01-10       563           0.0679            49.39           38        1876.82
# 2025-01-11       288           0.0511            46.07           15         691.05
# 2025-01-12       302           0.0339            72.90           10         729.00
# 2025-01-13       273           0.0300            42.82            8         342.56
# 2025-01-14       333           0.0499            50.33           17         855.61
# 2025-01-15       270           0.0550            50.28           15         754.20
# 2025-01-16       339           0.0311            50.28           11         553.08
# 2025-01-17       524           0.0209            50.55           11         556.05
# 2025-01-18       380           0.0483            45.18           18         813.24
# 2025-01-19       569           0.0637            44.17           36        1590.12
# 2025-01-20       379           0.0751            41.38           28        1158.64
# 2025-01-21       310           0.0575            35.12           18         632.16
# 2025-01-22       515           0.0750            52.16           39        2034.24
# 2025-01-23       527           0.0719            59.84           38        2273.92
# 2025-01-24       544           0.0331            44.57           18         802.26
# 2025-01-25       555           0.0720            44.41           40        1776.40
# 2025-01-26       210           0.0638            46.84           13         608.92
# 2025-01-27       405           0.0367            45.39           15         680.85
# 2025-01-28       307           0.0678            35.64           21         748.44
# 2025-01-29       297           0.0719            63.65           21        1336.65
# 2025-01-30       296           0.0380            54.39           11         598.29
# 2025-01-31       529           0.0516            42.88           27        1157.76
# 2025-02-01       516           0.0243            52.97           13         688.61
# 2025-02-02       285           0.0550            45.62           16         729.92
